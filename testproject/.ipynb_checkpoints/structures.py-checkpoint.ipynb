# %% [markdown]
# # This shows how to define and use custom structures for pyagb / pymap

# %%
import agb.agbrom
import agb.types
import agb.structure
import pymap.project
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-0c1de330e3a8> in <module>()
#       2 import agb.types
#       3 import agb.structure
# ----> 4 import pymap.old.project
#
# /media/d/romhacking/pyagb/pymap/old/project.py in <module>()
#       1 #!/usr/bin/python3
#       2
# ----> 3 from . import mapheader, tileset, image, constants, ow_imgs, path
#       4 import json
#       5 import os
#
# /media/d/romhacking/pyagb/pymap/old/ow_imgs.py in <module>()
#       8 import tempfile
#       9 from . import image as pyimage
# ---> 10 import agb.img_dump
#      11 import agb.agbrom
#      12 import os
#
# ModuleNotFoundError: No module named 'agb.img_dump'
